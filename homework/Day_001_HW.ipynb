# %% [markdown]
# 作業1：
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# 3. 蒐集而來的資料型態為何
#
# 4. 這組資料想解決的問題如何評估

# %% [markdown]
# 回答1:
#
# 我選擇DJIA 30 Stock Time Series
#
# 1.
# 這組指數資料是美國工業發展的領先指標
#
# 2.
# 資料來源是提供者用Python從Google Finance上抓的，涵蓋2006-2018年DJIA 30及其成分股的股價資料
#
# 3.
# DataFrame
# 包含Open High Low Close Volume Name等欄位
#
# 4.
# 我們可以用這組資料來檢視指數是否真實反映美國工業發展狀況，
# 也可以用來預測美國工業生產指數。
# MSE、MAE都可以是指標

# %% [markdown]
# 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# 3. 蒐集而來的資料型態為何
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)

# %% [markdown]
# 回答2:
#
# 1.
# 業績就是PxQ，因此要提升業績我們可以從兩方面著手，核心問題便是如何提升Q或是提升P。
#
# 提升P有幾種方法，提升品質、增加服務、保險、安全、方bang、效率，可以透過顧客滿意度調查是否有哪些地方是可以加強，或是顧客迫切需要的，改善或是新增這些便可以有更多的pricing power，增加p。
#
# 要提升Q可以透過分析目前客戶的年齡、職業等客戶特徵，為客戶分類，了解自己的客戶之後便能知道仍有哪些有需求但尚未開發的客戶族群，透過各種族群能接觸的媒介行銷自己，擴增客源。再來也可以透過客戶的搭乘狀況尋找適合的司機，若透過資料發現某地區司機供不應求，便需要主動去尋找潛在的司機，增加產能。
#
# 2.
# 資料可能是從平台而來，也許是顧客滿意度調查、客戶乘車紀錄、客戶註冊身份紀錄。
#
# 3.
# 資料可能是簡答形式、、1~10分的滿意程度、乘車紀錄可能是dataframe 日期時間  乘車地點 目的地等資料
#
# 4.
# 可以透過統計檢定來判斷改變後業績是否顯著提升

# %% [markdown]
# 作業3：
#
# 請點選下方檢視範例依照 Day_001_example_of_metrics.ipynb 完成 Mean Squared Error 的函式
#
# 資料夾結構建立規則提醒：2nd-ML100Days > data資料夾 & homework資料夾 (ipynb檔)
#
# (請注意data的存放位置，建議放在*.ipynb 同一個目錄下，這樣才能在不修改code的情況下正常執行)

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, y_hat):
    MSE = sum(y - y_hat) ** 2 / len(y)
    return MSE

def mean_absolute_error(y, y_hat):
    MAE = sum(abs(y - y_hat))/ len(y)
    return MAE

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 5.681
# The Mean absolute error is 10.788
